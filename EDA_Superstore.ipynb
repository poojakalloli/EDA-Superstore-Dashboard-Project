# %% [markdown]
# # Corporate-Grade Deep EDA-- Step-By-Step
#
# # Superstore Data set

# %%
# Importing important libaries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# # 1.Import dataset

# %%
df=pd.read_csv("Superstore_Management_System.csv")
df
# Out:
#     Order ID  Order Date   Ship Date Customer ID        Customer Name  \
# 0    ORD1000  2025-06-06  2025-06-09     CUST405      Michael Salazar
# 1    ORD1001  2025-07-15  2025-07-21     CUST264  Christine Whitehead
# 2    ORD1002  2024-09-07  2024-09-11     CUST182        Tracy Ramirez
# 3    ORD1003  2025-05-11  2025-05-12     CUST815   Christopher Murray
# 4    ORD1004  2024-10-21  2024-10-28     CUST777     Brittney Pollard
# ..       ...         ...         ...         ...                  ...
# 995  ORD1995  2024-10-31  2024-11-02     CUST790       Gregory Brooks
# 996  ORD1996  2024-09-12  2024-09-16     CUST649  Jennifer Morales MD
# 997  ORD1997  2025-11-22  2025-11-27     CUST898          Barry Knapp
# 998  ORD1998  2025-02-07  2025-02-08     CUST908          Sara Nelson
# 999  ORD1999  2025-06-14  2025-06-15     CUST632        Donald Hunter
#
#     Customer Segment Product ID  Product Name         Category Region  ...  \
# 0           Consumer   PROD2679   Cooking Oil          Grocery   East  ...
# 1           Consumer   PROD3511       Monitor      Electronics  South  ...
# 2          Corporate   PROD4806   Study Table        Furniture   East  ...
# 3        Home Office   PROD8913       Monitor      Electronics   East  ...
# 4        Home Office   PROD8613           Pen  Office Supplies   West  ...
# ..               ...        ...           ...              ...    ...  ...
# 995      Home Office   PROD6261   File Folder  Office Supplies  South  ...
# 996        Corporate   PROD7323     Bookshelf        Furniture   West  ...
# 997      Home Office   PROD2661          Sofa        Furniture   West  ...
# 998        Corporate   PROD1189       Monitor      Electronics   East  ...
# 999         Consumer   PROD7476  Office Chair        Furniture  South  ...
#
#     Sales Amount Cost Price    Profit  Stock Left  Auto Reorder  \
# 0        4903.65    3961.55    942.10          40            No
# 1        6433.40    4435.63   1997.77           1           Yes
# 2        6580.00    5252.78   1327.22          39            No
# 3       33023.70   22307.54  10716.16          19            No
# 4       21800.00   13278.23   8521.77          19            No
# ..           ...        ...       ...         ...           ...
# 995     16083.00   11251.41   4831.59          42            No
# 996     29908.80   25503.55   4405.25          16            No
# 997     21982.50   17162.73   4819.77          38            No
# 998       409.60     357.00     52.60           5           Yes
# 999      1434.80    1170.87    263.93          44            No
#
#      Reorder Quantity                  Supplier Name  \
# 0                   0               Gutierrez-Torres
# 1                  40  Gallegos, Rodriguez and Yates
# 2                   0                    Simmons LLC
# 3                   0                       Ford LLC
# 4                   0    Martin, Singh and Hernandez
# ..                ...                            ...
# 995                 0                   Jennings Ltd
# 996                 0       Montoya, Kim and Schultz
# 997                 0                    Jackson PLC
# 998                35  Fleming, Johnson and Trujillo
# 999                 0                      Henry Inc
#
#                       Supplier Email  Payment Mode Delivery Status
# 0              jonesregina@smith.biz          Cash         Pending
# 1       hernandezdeanna@campbell.org   Credit Card       Cancelled
# 2            egreen@smith-graves.com           UPI        Returned
# 3              rramirez@thompson.com          Cash       Delivered
# 4               lopezcarla@lynch.org          Cash         Pending
# ..                               ...           ...             ...
# 995  jessicamorris@powell-grimes.org          Cash       Delivered
# 996      boonepamela@brown-clark.com   Credit Card        Returned
# 997                 karl71@smith.com   Credit Card       Cancelled
# 998           yhudson@washington.net           UPI       Delivered
# 999             william30@harvey.com   Credit Card        Returned
#
# [1000 rows x 25 columns]

# %% [markdown]
# # Basic Analysis

# %% [markdown]
# ## 2.Finding Head

# %%
df.head()
# Out:
#   Order ID  Order Date   Ship Date Customer ID        Customer Name  \
# 0  ORD1000  2025-06-06  2025-06-09     CUST405      Michael Salazar
# 1  ORD1001  2025-07-15  2025-07-21     CUST264  Christine Whitehead
# 2  ORD1002  2024-09-07  2024-09-11     CUST182        Tracy Ramirez
# 3  ORD1003  2025-05-11  2025-05-12     CUST815   Christopher Murray
# 4  ORD1004  2024-10-21  2024-10-28     CUST777     Brittney Pollard
#
#   Customer Segment Product ID Product Name         Category Region  ...  \
# 0         Consumer   PROD2679  Cooking Oil          Grocery   East  ...
# 1         Consumer   PROD3511      Monitor      Electronics  South  ...
# 2        Corporate   PROD4806  Study Table        Furniture   East  ...
# 3      Home Office   PROD8913      Monitor      Electronics   East  ...
# 4      Home Office   PROD8613          Pen  Office Supplies   West  ...
#
#   Sales Amount Cost Price    Profit  Stock Left  Auto Reorder  \
# 0      4903.65    3961.55    942.10          40            No
# 1      6433.40    4435.63   1997.77           1           Yes
# 2      6580.00    5252.78   1327.22          39            No
# 3     33023.70   22307.54  10716.16          19            No
# 4     21800.00   13278.23   8521.77          19            No
#
#    Reorder Quantity                  Supplier Name  \
# 0                 0               Gutierrez-Torres
# 1                40  Gallegos, Rodriguez and Yates
# 2                 0                    Simmons LLC
# 3                 0                       Ford LLC
# 4                 0    Martin, Singh and Hernandez
#
#                  Supplier Email  Payment Mode Delivery Status
# 0         jonesregina@smith.biz          Cash         Pending
# 1  hernandezdeanna@campbell.org   Credit Card       Cancelled
# 2       egreen@smith-graves.com           UPI        Returned
# 3         rramirez@thompson.com          Cash       Delivered
# 4          lopezcarla@lynch.org          Cash         Pending
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 3.Finding Tail

# %%
df.tail()
# Out:
#     Order ID  Order Date   Ship Date Customer ID        Customer Name  \
# 995  ORD1995  2024-10-31  2024-11-02     CUST790       Gregory Brooks
# 996  ORD1996  2024-09-12  2024-09-16     CUST649  Jennifer Morales MD
# 997  ORD1997  2025-11-22  2025-11-27     CUST898          Barry Knapp
# 998  ORD1998  2025-02-07  2025-02-08     CUST908          Sara Nelson
# 999  ORD1999  2025-06-14  2025-06-15     CUST632        Donald Hunter
#
#     Customer Segment Product ID  Product Name         Category Region  ...  \
# 995      Home Office   PROD6261   File Folder  Office Supplies  South  ...
# 996        Corporate   PROD7323     Bookshelf        Furniture   West  ...
# 997      Home Office   PROD2661          Sofa        Furniture   West  ...
# 998        Corporate   PROD1189       Monitor      Electronics   East  ...
# 999         Consumer   PROD7476  Office Chair        Furniture  South  ...
#
#     Sales Amount Cost Price   Profit  Stock Left  Auto Reorder  \
# 995      16083.0   11251.41  4831.59          42            No
# 996      29908.8   25503.55  4405.25          16            No
# 997      21982.5   17162.73  4819.77          38            No
# 998        409.6     357.00    52.60           5           Yes
# 999       1434.8    1170.87   263.93          44            No
#
#      Reorder Quantity                  Supplier Name  \
# 995                 0                   Jennings Ltd
# 996                 0       Montoya, Kim and Schultz
# 997                 0                    Jackson PLC
# 998                35  Fleming, Johnson and Trujillo
# 999                 0                      Henry Inc
#
#                       Supplier Email  Payment Mode Delivery Status
# 995  jessicamorris@powell-grimes.org          Cash       Delivered
# 996      boonepamela@brown-clark.com   Credit Card        Returned
# 997                 karl71@smith.com   Credit Card       Cancelled
# 998           yhudson@washington.net           UPI       Delivered
# 999             william30@harvey.com   Credit Card        Returned
#
# [5 rows x 25 columns]

# %% [markdown]
# ## 4.Finding type

# %%
f"Data Type Is:{type(df)}"
# Out:
# "Data Type Is:<class 'pandas.core.frame.DataFrame'>"

# %% [markdown]
# ## 5.Finding Data Type For Each Columns

# %%
df.dtypes
# Out:
# Order ID             object
# Order Date           object
# Ship Date            object
# Customer ID          object
# Customer Name        object
# Customer Segment     object
# Product ID           object
# Product Name         object
# Category             object
# Region               object
# State                object
# City                 object
# Quantity              int64
# Unit Price            int64
# Discount (%)          int64
# Sales Amount        float64
# Cost Price          float64
# Profit              float64
# Stock Left            int64
# Auto Reorder         object
# Reorder Quantity      int64
# Supplier Name        object
# Supplier Email       object
# Payment Mode         object
# Delivery Status      object
# dtype: object

# %% [markdown]
# ## 6. Finding Random sample from Dataset

# %%
df.sample(4)
# Out:
#     Order ID  Order Date   Ship Date Customer ID  Customer Name  \
# 806  ORD1806  2024-06-11  2024-06-17     CUST939  Anthony Keith
# 392  ORD1392  2025-07-13  2025-07-14     CUST440    James Jones
# 167  ORD1167  2025-11-30  2025-12-02     CUST374  Tristan Allen
# 85   ORD1085  2025-05-24  2025-05-27     CUST131  Adriana Craig
#
#     Customer Segment Product ID  Product Name   Category Region  ...  \
# 806        Corporate   PROD4761      Rice Bag    Grocery   East  ...
# 392        Corporate   PROD8981   Cooking Oil    Grocery   West  ...
# 167         Consumer   PROD3313  Office Chair  Furniture  South  ...
# 85         Corporate   PROD6002     Bookshelf  Furniture  North  ...
#
#     Sales Amount Cost Price    Profit  Stock Left  Auto Reorder  \
# 806     18030.60   13270.44   4760.16          45            No
# 392     28158.80   23652.66   4506.14           0           Yes
# 167      4579.20    3967.88    611.32           2           Yes
# 85      37431.45   26128.72  11302.73           9           Yes
#
#      Reorder Quantity                 Supplier Name  \
# 806                 0                    Rice-Jones
# 392                29     Hayden, Herring and Frost
# 167                36  Martinez, Kerr and Cervantes
# 85                 48                 Hernandez Ltd
#
#                  Supplier Email  Payment Mode Delivery Status
# 806     scott50@grant-evans.com   Net Banking        Returned
# 392        madison93@davies.net   Credit Card        Returned
# 167  candiceherring@gardner.com   Net Banking       Delivered
# 85   nicole53@graham-wilson.com           UPI       Delivered
#
# [4 rows x 25 columns]

# %% [markdown]
# ## 7.Finding Summary of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order ID          1000 non-null   object
#  1   Order Date        1000 non-null   object
#  2   Ship Date         1000 non-null   object
#  3   Customer ID       1000 non-null   object
#  4   Customer Name     1000 non-null   object
#  5   Customer Segment  1000 non-null   object
#  6   Product ID        1000 non-null   object
#  7   Product Name      1000 non-null   object
#  8   Category          1000 non-null   object
#  9   Region            1000 non-null   object
#  10  State             1000 non-null   object
#  11  City              1000 non-null   object
#  12  Quantity          1000 non-null   int64
#  13  Unit Price        1000 non-null   int64
#  14  Discount (%)      1000 non-null   int64
#  15  Sales Amount      1000 non-null   float64
#  16  Cost Price        1000 non-null   float64
#  17  Profit            1000 non-null   float64
#  18  Stock Left        1000 non-null   int64
#  19  Auto Reorder      1000 non-null   object
#  20  Reorder Quantity  1000 non-null   int64
#  21  Supplier Name     1000 non-null   object
#  22  Supplier Email    1000 non-null   object
#  23  Payment Mode      1000 non-null   object
#  24  Delivery Status   1000 non-null   object
# dtypes: float64(3), int64(5), object(17)
# memory usage: 195.4+ KB

# %% [markdown]
# ## 8.Finding all Columns Name

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Customer ID', 'Customer Name',
#        'Customer Segment', 'Product ID', 'Product Name', 'Category', 'Region',
#        'State', 'City', 'Quantity', 'Unit Price', 'Discount (%)',
#        'Sales Amount', 'Cost Price', 'Profit', 'Stock Left', 'Auto Reorder',
#        'Reorder Quantity', 'Supplier Name', 'Supplier Email', 'Payment Mode',
#        'Delivery Status'],
#       dtype='object')

# %% [markdown]
# ## 9.Find All Data

# %%
pd.set_option("display.max_rows",None)
df
# Out:
#     Order ID  Order Date   Ship Date Customer ID              Customer Name  \
# 0    ORD1000  2025-06-06  2025-06-09     CUST405            Michael Salazar
# 1    ORD1001  2025-07-15  2025-07-21     CUST264        Christine Whitehead
# 2    ORD1002  2024-09-07  2024-09-11     CUST182              Tracy Ramirez
# 3    ORD1003  2025-05-11  2025-05-12     CUST815         Christopher Murray
# 4    ORD1004  2024-10-21  2024-10-28     CUST777           Brittney Pollard
# 5    ORD1005  2024-12-17  2024-12-18     CUST975              Jessica Hanna
# 6    ORD1006  2025-11-11  2025-11-15     CUST444               Donald Salas
# 7    ORD1007  2024-10-11  2024-10-12     CUST771          Annette Maldonado
# 8    ORD1008  2026-02-09  2026-02-15     CUST264         William Montgomery
# 9    ORD1009  2024-10-30  2024-11-06     CUST113             Connie Jackson
# 10   ORD1010  2026-01-17  2026-01-23     CUST395                Claire Wood
# 11   ORD1011  2024-12-16  2024-12-23     CUST362              Julie Simmons
# 12   ORD1012  2024-11-30  2024-12-01     CUST475               Tammy Clarke
# 13   ORD1013  2026-01-21  2026-01-26     CUST830                Robin Adams
# 14   ORD1014  2024-11-28  2024-12-05     CUST492              Mark Morrison
# 15   ORD1015  2025-10-16  2025-10-21     CUST100          Anthony Rodriguez
# 16   ORD1016  2025-11-16  2025-11-17     CUST161           Cameron Figueroa
# 17   ORD1017  2024-08-09  2024-08-10     CUST392               David Gentry
# 18   ORD1018  2024-08-15  2024-08-21     CUST241            Jessica Mercado
# 19   ORD1019  2025-07-28  2025-08-01     CUST620                Sean Rivera
# 20   ORD1020  2025-01-01  2025-01-03     CUST390            William Goodwin
# 588  ORD1588  2025-07-24  2025-07-30     CUST280               Michael Pena
# 589  ORD1589  2025-04-07  2025-04-09     CUST816            Rebecca Manning
# 590  ORD1590  2024-07-07  2024-07-14     CUST305              Andrea Sexton
# 591  ORD1591  2025-09-02  2025-09-07     CUST780               Jack Schmitt
# 592  ORD1592  2026-02-24  2026-03-02     CUST310              Amanda Flores
# 593  ORD1593  2025-04-04  2025-04-10     CUST823               Timothy King
# 594  ORD1594  2025-10-20  2025-10-23     CUST431             Leslie Summers
# 595  ORD1595  2025-09-15  2025-09-20     CUST162                Misty Lewis
# 596  ORD1596  2025-09-05  2025-09-12     CUST391                Jeremy Cole
# 597  ORD1597  2024-08-19  2024-08-23     CUST526           Victor Henderson
# 598  ORD1598  2025-11-24  2025-11-28     CUST539                 Janet Ross
# 599  ORD1599  2025-06-12  2025-06-19     CUST581             Kristin Mcneil
# 600  ORD1600  2025-04-03  2025-04-05     CUST391          Margaret Williams
# 601  ORD1601  2026-02-04  2026-02-07     CUST924              Yolanda Ramos
# 602  ORD1602  2025-04-05  2025-04-09     CUST894                 Gina Smith
# 603  ORD1603  2025-12-03  2025-12-08     CUST292          Christian Gardner
# 604  ORD1604  2025-05-15  2025-05-20     CUST107              Garrett Jones
# 605  ORD1605  2025-09-04  2025-09-07     CUST671              Kathy Gilmore
# ...
# 793                   christopher06@reed.net   Net Banking        Returned
# 794                  qrodriguez@figueroa.com           UPI       Cancelled
# 795            monicanewton@chapman-wall.com   Credit Card       Delivered
# 796                    dburnett@phillips.org           UPI         Pending
# 797                  eugeneperez@jackson.com          Cash        Returned
# 798                    ashley79@phillips.com   Net Banking       Cancelled
# 799             jonesbenjamin@cunningham.net          Cash        Returned
# 800                          asmith@cook.com   Net Banking         Pending
# 801                     daniel00@cooper.info   Net Banking        Returned
# 802                       rsmith@johnson.org          Cash       Delivered
# 803                  hawkinsroberta@bush.com          Cash        Returned
# 804                        mdaniel@perry.com   Credit Card        Returned
# 805            donald66@contreras-bender.com   Net Banking       Cancelled
# 806                  scott50@grant-evans.com   Net Banking        Returned
# 807                estradaphilip@haynes.info           UPI         Pending
# 808                 alyssadiaz@dominguez.com   Net Banking       Delivered
# 809                        fwilson@white.com   Net Banking        Returned
# 810                      jsimpson@ingram.com          Cash        Returned
# 811     stephanieholloway@chapman-steele.com   Credit Card       Delivered
# 812                       nicole32@jones.com   Net Banking       Delivered
# 813              wbaldwin@lawson-francis.com          Cash         Pending
# 814                rossjulie@garcia-wood.com   Net Banking       Delivered
# 815                megan83@vaughn-archer.com           UPI       Delivered
# 816                   perezshannon@davis.com   Credit Card       Delivered
# 817                    jimmyleonard@hill.com   Credit Card       Delivered
# 818                         eweber@lane.info   Credit Card       Cancelled
# 819                          owood@dixon.com           UPI         Pending
# 820              christophergreen@parker.com   Credit Card       Cancelled
# 821                     umoore@richmond.info   Net Banking       Cancelled
# 822                      taylor06@carter.com           UPI       Delivered
# 823              nmarquez@fields-andrews.com           UPI        Returned
# 824                   martinjoseph@moran.com   Credit Card       Cancelled
# 825            gloria35@hernandez-sawyer.biz   Net Banking       Cancelled
# 826                  fguerrero@hull-mann.com          Cash         Pending
# 827                   ulandry@valenzuela.org           UPI       Cancelled
# 828                 samuellarson@andrade.com           UPI       Delivered
# 829               christopherweiss@klein.org          Cash         Pending
# 830     francisthompson@sanchez-johnson.info   Net Banking       Delivered
# 831                     ashley52@graham.info   Credit Card        Returned
# 832                        zglenn@duncan.org   Net Banking        Returned
# 833             sbutler@williams-johnson.biz   Credit Card        Returned
# 834         hernandezlucas@cruz-schaefer.com   Net Banking       Delivered
# 835                    lhall@lopez-green.com   Net Banking        Returned
# 836                        gmiller@huang.com          Cash         Pending
# 837                      connie09@thomas.com           UPI       Delivered
# 838                  katiesanchez@vaughn.com   Net Banking       Delivered
# 839                   joannemoore@walker.com   Credit Card        Returned
# 840                        larry23@mason.com           UPI       Delivered
# 841              joseph15@thomas-bradley.net   Net Banking         Pending
# 842                    fosterjose@sparks.com   Credit Card       Cancelled
# 843          carlsonlawrence@perry-lewis.com   Credit Card        Returned
# 844               maria37@valencia-olson.biz   Credit Card        Returned
# 845                         derek83@tran.com          Cash        Returned
# 846                          eric78@cobb.biz           UPI        Returned
# 847                   qwest@nelson-smith.com           UPI       Cancelled
# 848                     eprice@cervantes.com          Cash        Returned
# 849                  tylerheath@johnson.info   Net Banking       Delivered
# 850                      qmcdonald@evans.biz           UPI       Delivered
# 851                         iscott@kelly.com   Credit Card       Cancelled
# 852                   gregorynash@snyder.com   Credit Card       Delivered
# 853                      charles49@jones.com   Credit Card         Pending
# 854                      james88@parsons.com           UPI       Delivered
# 855                 dpittman@smith-smith.com   Net Banking       Cancelled
# 856                        lreyes@huerta.com   Credit Card        Returned
# 857                  laurieclark@english.com           UPI       Delivered
# 858                 ronaldwalker@hartman.com   Credit Card       Cancelled
# 859                    hmartin@donaldson.com          Cash        Returned
# 860                        erika87@short.com           UPI        Returned
# 861                dennis17@brewer-perez.com   Credit Card       Delivered
# 862                  tarastephens@morgan.net   Credit Card       Delivered
# 863                   kkrueger@frederick.com   Credit Card       Cancelled
# 864                     isnyder@williams.net   Net Banking       Delivered
# 865                haileyfleming@johnson.biz           UPI       Cancelled
# 866                        hwilson@reyes.net           UPI        Returned
# 867              gosborne@haley-anderson.net          Cash       Delivered
# 868               diazamanda@evans-chung.net   Credit Card        Returned
# 869                     wangsamuel@hill.info   Credit Card       Cancelled
# 870               rodriguezreginald@wood.com   Credit Card       Cancelled
# 871                          kjones@fry.info   Net Banking         Pending
# 872                    joshua85@stevens.info           UPI       Cancelled
# 873                  parrishjoseph@moyer.org          Cash         Pending
# 874                        keith50@patel.com           UPI        Returned
# 875                        udiaz@garrett.net   Credit Card       Delivered
# 876                     joshua65@rodgers.com   Net Banking       Cancelled
# 877                         usutton@hunt.com   Credit Card        Returned
# 878                       xballard@blair.org           UPI         Pending
# 879                     heather20@cooper.org   Credit Card         Pending
# 880          cummingsrebecca@jones-smith.com           UPI        Returned
# 881           melvinjarvis@harris-miller.com   Net Banking        Returned
# 882     christinarodgers@carlson-walker.info          Cash       Delivered
# 883                christopherhart@ortiz.com           UPI         Pending
# 884                     bellbarbara@shaw.com   Net Banking       Cancelled
# 885                 amber06@white-graves.com   Credit Card         Pending
# 886                      mmartinez@ward.info   Credit Card       Cancelled
# 887                 chadcaldwell@edwards.net   Net Banking        Returned
# 888                      matthew57@jones.com   Net Banking         Pending
# 889                        sjensen@burns.com   Net Banking       Cancelled
# 890                 wendybryant@williams.com   Net Banking        Returned
# 891                     xmartin@williams.biz   Net Banking        Returned
# 892                   uwhite@moran-king.info   Credit Card       Delivered
# 893                    mmaldonado@fields.biz          Cash       Cancelled
# 894                  randallcastro@wyatt.com   Net Banking       Delivered
# 895                     william35@burton.net   Credit Card         Pending
# 896           hawkinsnicole@hicks-morris.com   Credit Card       Delivered
# 897                  jennifer82@mitchell.com   Credit Card       Delivered
# 898               brittanybrock@browning.com           UPI       Delivered
# 899                 calvinvargas@webster.org   Net Banking        Returned
# 900                        wacosta@ellis.com          Cash         Pending
# 901              carolynsmith@cook-smith.com          Cash       Cancelled
# 902                 brenda01@mora-miller.com   Net Banking       Delivered
# 903          sdaniels@williams-hamilton.info           UPI       Cancelled
# 904                kevincompton@williams.net           UPI       Delivered
# 905             kevinmcconnell@brown-fox.com   Net Banking        Returned
# 906              butlerelizabeth@schultz.com          Cash        Returned
# 907               kelsey16@bell-nielsen.info          Cash       Cancelled
# 908                 andrewsdavid@hancock.com          Cash         Pending
# 909                 smithcourtney@howard.com   Net Banking        Returned
# 910                     lbishop@mckinney.com           UPI         Pending
# 911                    amystewart@berry.info   Credit Card         Pending
# 912               elizabethbullock@brown.net           UPI         Pending
# 913               williamblackwell@owen.info          Cash        Returned
# 914                           bgill@reid.com           UPI       Delivered
# 915                       thayden@boyle.info   Credit Card         Pending
# 916         jennifermiller@navarro-smith.net          Cash         Pending
# 917               stephenscharles@bowers.com          Cash        Returned
# 918               jonesamanda@davenport.info          Cash        Returned
# 919                  burkerichard@vaughn.com   Net Banking       Cancelled
# 920                    jameskelley@kelly.com          Cash        Returned
# 921         austinnicholas@wilson-obrien.biz           UPI         Pending
# 922              woodardelizabeth@brooks.com   Net Banking        Returned
# 923             rodriguezjonathan@hurley.net           UPI         Pending
# 924                 esmith@whitney-smith.com   Credit Card         Pending
# 925                       megan01@miller.biz   Net Banking       Cancelled
# 926                  turnerdesiree@vance.com          Cash        Returned
# 927                      pellis@fox-west.com           UPI        Returned
# 928             maryglover@diaz-spencer.info   Net Banking         Pending
# 929                     bwillis@thompson.com           UPI       Cancelled
# 930              doughertymatthew@gordon.com           UPI       Cancelled
# 931                 lisa40@roth-robinson.com   Net Banking         Pending
# 932        frederickheather@craig-peters.org           UPI       Delivered
# 933                         znelson@mayo.com   Net Banking         Pending
# 934                   jgood@butler-mejia.biz   Net Banking       Cancelled
# 935               avilarhonda@price-tran.com   Net Banking       Cancelled
# 936                 orivera@olsen-wilson.org          Cash       Delivered
# 937                      sstephens@allen.com           UPI       Delivered
# 938                        holly55@foley.com   Credit Card        Returned
# 939             regina73@smith-martinez.info           UPI         Pending
# 940              cunninghammichael@dixon.org          Cash         Pending
# 941                 trevorcurtis@walker.info           UPI       Cancelled
# 942                        lsilva@tanner.org           UPI        Returned
# 943                   anthonyallen@lewis.org          Cash       Delivered
# 944        pattersonsteven@davis-cochran.net   Net Banking       Cancelled
# 945         catherinesmith@barnes-hodges.com   Credit Card       Cancelled
# 946                    travisbell@arnold.net          Cash        Returned
# 947                         lisa34@smith.biz   Net Banking       Cancelled
# 948                  howardedward@rogers.com          Cash        Returned
# 949              smithjesus@cook-watkins.org          Cash         Pending
# 950                    charles35@leonard.com          Cash        Returned
# 951                      bandrade@miller.com   Net Banking        Returned
# 952            jenniferchandler@sanders.info   Credit Card         Pending
# 953                   dkeller@tyler-hess.net   Net Banking         Pending
# 954                         elove@lester.com           UPI         Pending
# 955             jasmine74@gilbert-martin.com   Credit Card       Delivered
# 956                    ianderson@rosales.net   Credit Card       Delivered
# 957                    lindamoore@parker.com   Net Banking         Pending
# 958                      brandon61@brady.org   Credit Card        Returned
# 959                   brianowens@gilbert.org           UPI       Delivered
# 960         millerdennis@greer-zimmerman.com   Credit Card         Pending
# 961                         vperez@smith.com   Net Banking         Pending
# 962                       travis08@king.info   Credit Card       Cancelled
# 963                     alfredhall@young.com          Cash       Delivered
# 964                 diane22@blake-george.com   Net Banking         Pending
# 965                     cindy35@figueroa.com           UPI        Returned
# 966                 fcooper@brown-bailey.com   Credit Card        Returned
# 967                  jamie80@burke-white.com           UPI        Returned
# 968                ronald46@edwards-wolf.com   Credit Card       Cancelled
# 969                         vlove@waters.org   Net Banking        Returned
# 970   walkermichael@mccullough-gutierrez.net   Credit Card       Delivered
# 971              ingramjoe@green-walters.net           UPI       Delivered
# 972              woodsmarco@waters-smith.com   Net Banking         Pending
# 973                    nmack@mckee-haney.com   Credit Card       Cancelled
# 974                ethansullivan@vazquez.net   Credit Card       Cancelled
# 975                   balljeff@tran-hall.biz   Credit Card         Pending
# 976                   benjaminking@davis.com   Credit Card        Returned
# 977                parkerannette@greene.info   Credit Card       Delivered
# 978                 floresmary@christian.org   Credit Card         Pending
# 979              nthomas@peterson-larson.com   Credit Card         Pending
# 980                    matthew09@hampton.net          Cash       Delivered
# 981                 oortega@adams-miller.com   Credit Card       Delivered
# 982               robin21@robbins-bailey.biz          Cash         Pending
# 983                 rayphillip@whitehead.com          Cash        Returned
# 984                    kathleen70@morris.com           UPI       Cancelled
# 985                     hartian@humphrey.com   Net Banking       Delivered
# 986            robert18@little-contreras.com   Credit Card         Pending
# 987                     ndurham@jimenez.info   Net Banking         Pending
# 988                       emartinez@cruz.com          Cash        Returned
# 989            yhess@christensen-herrera.com          Cash       Cancelled
# 990                julia23@mosley-jordan.com   Credit Card       Cancelled
# 991         jamiemcguire@holloway-castro.com           UPI         Pending
# 992      georgewarner@fletcher-bartlett.info           UPI        Returned
# 993                  aliciasanders@hayes.com          Cash        Returned
# 994             robinsonstephen@reynolds.com          Cash       Cancelled
# 995          jessicamorris@powell-grimes.org          Cash       Delivered
# 996              boonepamela@brown-clark.com   Credit Card        Returned
# 997                         karl71@smith.com   Credit Card       Cancelled
# 998                   yhudson@washington.net           UPI       Delivered
# 999                     william30@harvey.com   Credit Card        Returned
#
# [1000 rows x 25 columns]

# %% [markdown]
# ## 10.Finding Out the Discription of Dataset

# %%
f"There are total rows and columns is :{df.shape}"
# Out:
# 'There are total rows and columns is :(1000, 25)'

# %% [markdown]
# ## 11.Finding Out Discription of Dataset

# %%
df.describe(include="object")
# Out:
#        Order ID  Order Date   Ship Date Customer ID     Customer Name  \
# count      1000        1000        1000        1000              1000
# unique     1000         549         548         622               993
# top     ORD1000  2025-09-04  2025-01-28     CUST264  Michael Robinson
# freq          1           5           7           5                 2
#
#        Customer Segment Product ID Product Name     Category Region   State  \
# count              1000       1000         1000         1000   1000    1000
# unique                3        946           20            4      4      50
# top            Consumer   PROD3107   Headphones  Electronics  North  Kansas
# freq                348          3           64          258    263      32
#
#                  City Auto Reorder      Supplier Name         Supplier Email  \
# count            1000         1000               1000                   1000
# unique            973            2                981                   1000
# top     Hernandezport           No  Thompson and Sons  jonesregina@smith.biz
# freq                3          799                  3                      1
#
#        Payment Mode Delivery Status
# count          1000            1000
# unique            4               4
# top     Credit Card        Returned
# freq            262             275

# %%
df.describe(include="int")
# Out:
#           Quantity   Unit Price  Discount (%)  Stock Left  Reorder Quantity
# count  1000.000000  1000.000000   1000.000000   1000.0000       1000.000000
# mean      5.427000  2529.355000      9.845000     24.1930          6.807000
# std       2.903981  1430.420992      6.928129     14.6001         14.211323
# min       1.000000   104.000000      0.000000      0.0000          0.000000
# 25%       3.000000  1344.500000      5.000000     12.0000          0.000000
# 50%       5.000000  2502.500000     10.000000     23.0000          0.000000
# 75%       8.000000  3801.750000     15.000000     37.0000          0.000000
# max      10.000000  4996.000000     20.000000     50.0000         50.000000

# %%
df.describe(include="float")
# Out:
#        Sales Amount   Cost Price        Profit
# count   1000.000000   1000.00000   1000.000000
# mean   12080.677300   9053.32759   3027.349710
# std    10139.498242   7677.90805   2896.393869
# min       93.600000     62.18000     29.660000
# 25%     3883.687500   2933.05750    907.975000
# 50%     9014.550000   6725.10500   2111.165000
# 75%    17811.000000  13239.57000   4339.157500
# max    46037.000000  36683.87000  17980.060000

# %% [markdown]
# ## 12.Finding  Missing values (Null value)

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Order Date          0
# Ship Date           0
# Customer ID         0
# Customer Name       0
# Customer Segment    0
# Product ID          0
# Product Name        0
# Category            0
# Region              0
# State               0
# City                0
# Quantity            0
# Unit Price          0
# Discount (%)        0
# Sales Amount        0
# Cost Price          0
# Profit              0
# Stock Left          0
# Auto Reorder        0
# Reorder Quantity    0
# Supplier Name       0
# Supplier Email      0
# Payment Mode        0
# Delivery Status     0
# dtype: int64

# %% [markdown]
# ## Data Anylsis

# %% [markdown]
# # DATA QUALITY CHECK

# %%
print("\n==== DATA Qqulity assessment ===")
#check for missing values
# check for missing values
missing_data = df.isnull().sum()

print("\n", missing_data[missing_data > 0])

# check for duplicates
print(f"\nDuplicate Rows: {df.duplicated().sum()}")
# Out:
# ==== DATA Qqulity assessment ===
#
#  Series([], dtype: int64)
#
# Duplicate Rows: 0

# %% [markdown]
# # Data Type Conversion

# %%
# convert date columns to datetime


df["Order Date"] = pd.to_datetime(df["Order Date"], format="%Y-%m-%d")
df["Ship Date"] = pd.to_datetime(df["Ship Date"], format="%Y-%m-%d")

#chcek coversion
print("\nDate columns converted:\n")
print(f"Order Date:{df["Order Date"].dtype}")
print(f"Ship Date:{df["Ship Date"].dtype}")
# Out:
# Date columns converted:
#
# Order Date:datetime64[ns]
# Ship Date:datetime64[ns]

# %% [markdown]
# # UNIVARIATE ANALYSIS

# %%
# univariate analysis is the simplest form of statistical analysis as the  name suggest-"uni"
print("\n=== CATACORICAL VARIABLES ===\n")

categorical_cols=["Customer Segment","Category","Region","Payment Mode","Delivery Status","Auto Reorder"]
for col in categorical_cols:
    print(f"\n--{col} ---")
    print(df[col].value_counts())

    #Visualization 
    plt.figure(figsize=(6,6))
    df[col].value_counts().plot(kind="bar",color="skyblue")
    plt.title(f"Distribution of {col}")
    plt.xticks(rotation=30)
    plt.tight_layout()
    plt.show()
# Out:
# === CATACORICAL VARIABLES ===
#
#
# --Customer Segment ---
# Customer Segment
# Consumer       348
# Home Office    342
# Corporate      310
# Name: count, dtype: int64
# --Category ---
# Category
# Electronics        258
# Grocery            255
# Furniture          255
# Office Supplies    232
# Name: count, dtype: int64
# --Region ---
# Region
# North    263
# South    257
# East     242
# West     238
# Name: count, dtype: int64
# --Payment Mode ---
# Payment Mode
# Credit Card    262
# Net Banking    251
# UPI            245
# Cash           242
# Name: count, dtype: int64
# --Delivery Status ---
# Delivery Status
# Returned     275
# Pending      258
# Delivered    244
# Cancelled    223
# Name: count, dtype: int64
# --Auto Reorder ---
# Auto Reorder
# No     799
# Yes    201
# Name: count, dtype: int64

# %% [markdown]
# # Numerical Aariables Analysis

# %%
print(r"\n== NUMERICAL VARIABLE ===\N")
numerical_cols=["Quantity","Unit Price","Discount (%)","Sales Amount","Cost Price", 'Profit','Stock Left','Reorder Quantity'] 
for col in numerical_cols:
    
    print("\n", col, "\n")
    
    print(f"Mean: {df[col].mean():.2f}")
    print(f"Median: {df[col].median():.2f}")
    print(f"Std Dev: {df[col].std():.2f}")
    print(f"Min: {df[col].min():.2f}")
    print(f"Max: {df[col].max():.2f}")

    # Visualization
    plt.figure(figsize=(8, 4))

    # Histogram
    plt.subplot(1, 2, 1)
    df[col].hist(bins=30, color='lightgreen', alpha=0.7)
    plt.title(f'Distribution of {col}')

    # Boxplot
    plt.subplot(1, 2, 2)
    df.boxplot(column=col)
    plt.title(f'Boxplot of {col}')

    plt.tight_layout()
    plt.show()
# Out:
# \n== NUMERICAL VARIABLE ===\N
#
#  Quantity
#
# Mean: 5.43
# Median: 5.00
# Std Dev: 2.90
# Min: 1.00
# Max: 10.00
#  Unit Price
#
# Mean: 2529.36
# Median: 2502.50
# Std Dev: 1430.42
# Min: 104.00
# Max: 4996.00
#  Discount (%)
#
# Mean: 9.85
# Median: 10.00
# Std Dev: 6.93
# Min: 0.00
# Max: 20.00
#  Sales Amount
#
# Mean: 12080.68
# Median: 9014.55
# Std Dev: 10139.50
# Min: 93.60
# Max: 46037.00
#  Cost Price
#
# Mean: 9053.33
# Median: 6725.10
# Std Dev: 7677.91
# Min: 62.18
# Max: 36683.87
#  Profit
#
# Mean: 3027.35
# Median: 2111.16
# Std Dev: 2896.39
# Min: 29.66
# Max: 17980.06
#  Stock Left
#
# Mean: 24.19
# Median: 23.00
# Std Dev: 14.60
# Min: 0.00
# Max: 50.00
#  Reorder Quantity
#
# Mean: 6.81
# Median: 0.00
# Std Dev: 14.21
# Min: 0.00
# Max: 50.00

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Customer ID', 'Customer Name',
#        'Customer Segment', 'Product ID', 'Product Name', 'Category', 'Region',
#        'State', 'City', 'Quantity', 'Unit Price', 'Discount (%)',
#        'Sales Amount', 'Cost Price', 'Profit', 'Stock Left', 'Auto Reorder',
#        'Reorder Quantity', 'Supplier Name', 'Supplier Email', 'Payment Mode',
#        'Delivery Status'],
#       dtype='object')

# %% [markdown]
# # BIVARIATE ANALYSIS

# %%
import matplotlib.pyplot as plt

print("\n=== SALES AND PROFIT BY CATEGORY ===\n")

# Grouping
category_performance = df.groupby("Category").agg({
    "Sales Amount": "sum",
    "Profit": "sum",
    "Order ID": "count"
}).rename(columns={"Order ID": "Order Count"})

# Profit Margin
category_performance["Profit Margin"] = (
    category_performance["Profit"] / category_performance["Sales Amount"]
) * 100

print(category_performance, "\n\n")

# Visualization
fig, axes = plt.subplots(2, 2, figsize=(15, 12))

# Sales by Category
category_performance["Sales Amount"].plot(
    kind="bar", ax=axes[0, 0], color="blue", alpha=0.7
)
axes[0, 0].set_title("Total Sales by Category")
axes[0, 0].tick_params(axis='x', rotation=30)

# Profit by Category
category_performance["Profit"].plot(
    kind="bar", ax=axes[0, 1], color="green", alpha=0.7
)
axes[0, 1].set_title("Total Profit by Category")
axes[0, 1].tick_params(axis='x', rotation=30)

# Profit Margin
category_performance["Profit Margin"].plot(
    kind="bar", ax=axes[1, 0], color="orange", alpha=0.7
)
axes[1, 0].set_title("Profit Margin (%)")
axes[1, 0].tick_params(axis='x', rotation=30)

# Order Count
category_performance["Order Count"].plot(
    kind="bar", ax=axes[1, 1], color="red", alpha=0.7
)
axes[1, 1].set_title("Order Count by Category")
axes[1, 1].tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()
# Out:
# === SALES AND PROFIT BY CATEGORY ===
#
#                  Sales Amount     Profit  Order Count  Profit Margin
# Category
# Electronics        2996987.75  751262.17          258      25.067242
# Furniture          3039481.40  757156.93          255      24.910728
# Grocery            3195391.95  835525.28          255      26.147818
# Office Supplies    2848816.20  683405.33          232      23.989099

# %% [markdown]
# ## Regional Performance

# %%
import matplotlib.pyplot as plt
import seaborn as sns

print("\n=== REGIONAL PERFORMANCE ===\n")

# Grouping by Region
regional_performance = df.groupby("Region").agg({
    "Sales Amount": "sum",
    "Profit": "sum",
    "Order ID": "count"
}).rename(columns={"Order ID": "Order Count"})

# Profit Margin
regional_performance["Profit Margin"] = (
    regional_performance["Profit"] / regional_performance["Sales Amount"]
) * 100

print(regional_performance, "\n\n")

# Visualization
plt.figure(figsize=(12, 8))

# 1. Sales Distribution (Pie Chart)
plt.subplot(2, 2, 1)
regional_performance["Sales Amount"].plot(
    kind="pie", autopct="%1.1f%%"
)
plt.title("Sales Distribution by Region")

# 2. Profit Distribution (Pie Chart)
plt.subplot(2, 2, 2)
regional_performance["Profit"].plot(
    kind="pie", autopct="%1.1f%%"
)
plt.title("Profit Distribution by Region")

# 3. Order Count (Bar Chart)
plt.subplot(2, 2, 3)
sns.barplot(
    x=regional_performance.index,
    y="Order Count",
    data=regional_performance
)
plt.title("Order Count by Region")
plt.xticks(rotation=30)

# 4. Profit Margin (Bar Chart)
plt.subplot(2, 2, 4)
sns.barplot(
    x=regional_performance.index,
    y="Profit Margin",
    data=regional_performance
)
plt.title("Profit Margin by Region (%)")
plt.xticks(rotation=30)

plt.tight_layout()
plt.show()
# Out:
# === REGIONAL PERFORMANCE ===
#
#         Sales Amount     Profit  Order Count  Profit Margin
# Region
# East      2821828.00  699020.46          242      24.771902
# North     3209945.85  837319.72          263      26.085167
# South     3140813.10  774462.55          257      24.658027
# West      2908090.35  716546.98          238      24.639777

# %% [markdown]
# ## Time Series Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

print("\n=== TIME SERIES ANALYSIS ===\n")

# Convert Order Date to datetime (if not already)
df["Order Date"] = pd.to_datetime(df["Order Date"])

# Extract time features
df["Order Month"] = df["Order Date"].dt.to_period("M")
df["Order Year"] = df["Order Date"].dt.year

# Monthly trends
monthly_trends = df.groupby("Order Month").agg({
    "Sales Amount": "sum",
    "Profit": "sum",
    "Order ID": "count"
}).rename(columns={"Order ID": "Order Count"})

print("Monthly Trends:")
print(monthly_trends.tail(10), "\n\n")

# Visualization
plt.figure(figsize=(15, 10))

# 1. Sales Trend
plt.subplot(3, 1, 1)
monthly_trends["Sales Amount"].plot(
    kind="line", color="blue", marker="o"
)
plt.title("Monthly Sales Trend")
plt.ylabel("Sales Amount")
plt.grid(True)

# 2. Profit Trend
plt.subplot(3, 1, 2)
monthly_trends["Profit"].plot(
    kind="line", color="green", marker="o"
)
plt.title("Monthly Profit Trend")
plt.ylabel("Profit")
plt.grid(True)

# 3. Order Count Trend
plt.subplot(3, 1, 3)
monthly_trends["Order Count"].plot(
    kind="line", color="red", marker="o"
)
plt.title("Monthly Order Count Trend")
plt.ylabel("Order Count")
plt.grid(True)

plt.tight_layout()
plt.show()
# Out:
# === TIME SERIES ANALYSIS ===
#
# Monthly Trends:
#              Sales Amount     Profit  Order Count
# Order Month
# 2025-07         561063.30  139124.13           38
# 2025-08         556391.65  144230.32           39
# 2025-09         508860.75  119649.59           43
# 2025-10         477137.35  122871.09           45
# 2025-11         399365.40  100241.66           41
# 2025-12         575038.35  146444.46           39
# 2026-01         691908.55  168200.45           49
# 2026-02         393344.05   68197.93           37
# 2026-03         484007.05  126887.63           39
# 2026-04         232636.65   54694.69           20

# %% [markdown]
# ##  ADVANCED ANALYSIS

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Correlation Matrix
correlation_matrix = df.corr(numeric_only=True)

print("Correlation Matrix:")
print(correlation_matrix, "\n\n")

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")
plt.show()
# Out:
# Correlation Matrix:
#                   Quantity  Unit Price  Discount (%)  Sales Amount  \
# Quantity          1.000000   -0.068733      0.024687      0.611697
# Unit Price       -0.068733    1.000000      0.047257      0.644244
# Discount (%)      0.024687    0.047257      1.000000     -0.040266
# Sales Amount      0.611697    0.644244     -0.040266      1.000000
# Cost Price        0.604733    0.634435     -0.029519      0.985037
# Profit            0.538331    0.573534     -0.062708      0.889544
# Stock Left        0.000817   -0.018550      0.004700     -0.018794
# Reorder Quantity -0.020219   -0.002594     -0.030550     -0.013412
# Order Year        0.022084   -0.046545     -0.027589     -0.004271
#
#                   Cost Price    Profit  Stock Left  Reorder Quantity  \
# Quantity            0.604733  0.538331    0.000817         -0.020219
# Unit Price          0.634435  0.573534   -0.018550         -0.002594
# Discount (%)       -0.029519 -0.062708    0.004700         -0.030550
# Sales Amount        0.985037  0.889544   -0.018794         -0.013412
# Cost Price          1.000000  0.797501   -0.010147         -0.021688
# Profit              0.797501  1.000000   -0.038893          0.010539
# Stock Left         -0.010147 -0.038893    1.000000         -0.652061
# Reorder Quantity   -0.021688  0.010539   -0.652061          1.000000
# Order Year          0.002689 -0.022077   -0.074622          0.067078
#
#                   Order Year
# Quantity            0.022084
# Unit Price         -0.046545
# Discount (%)       -0.027589
# Sales Amount       -0.004271
# Cost Price          0.002689
# Profit             -0.022077
# Stock Left         -0.074622
# Reorder Quantity    0.067078
# Order Year          1.000000

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Customer ID', 'Customer Name',
#        'Customer Segment', 'Product ID', 'Product Name', 'Category', 'Region',
#        'State', 'City', 'Quantity', 'Unit Price', 'Discount (%)',
#        'Sales Amount', 'Cost Price', 'Profit', 'Stock Left', 'Auto Reorder',
#        'Reorder Quantity', 'Supplier Name', 'Supplier Email', 'Payment Mode',
#        'Delivery Status', 'Order Month', 'Order Year'],
#       dtype='object')

# %% [markdown]
# ## Customer Segment Analysis

# %%
import matplotlib.pyplot as plt

print("\n=== CUSTOMER SEGMENT ANALYSIS ===\n")

# Grouping
segment_analysis = df.groupby('Customer Segment').agg({
    'Sales Amount': ['sum', 'mean'],
    'Profit': ['sum', 'mean'],
    'Order ID': 'count',
    'Discount (%)': 'mean'
}).round(2)

# Rename columns
segment_analysis.columns = [
    'Total Sales', 'Avg Sales',
    'Total Profit', 'Avg Profit',
    'Order Count', 'Avg Discount'
]

print(segment_analysis, "\n\n")

# Visualization
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# 1. Total Sales
segment_analysis['Total Sales'].plot(
    kind='bar', ax=axes[0, 0], color='lightblue'
)
axes[0, 0].set_title('Total Sales by Customer Segment')
axes[0, 0].tick_params(axis='x', rotation=30)

# 2. Total Profit
segment_analysis['Total Profit'].plot(
    kind='bar', ax=axes[0, 1], color='lightgreen'
)
axes[0, 1].set_title('Total Profit by Customer Segment')
axes[0, 1].tick_params(axis='x', rotation=30)

# 3. Average Profit
segment_analysis['Avg Profit'].plot(
    kind='bar', ax=axes[1, 0], color='orange'
)
axes[1, 0].set_title('Average Profit by Customer Segment')
axes[1, 0].tick_params(axis='x', rotation=30)

# 4. Average Discount
segment_analysis['Avg Discount'].plot(
    kind='bar', ax=axes[1, 1], color='red'
)
axes[1, 1].set_title('Average Discount by Customer Segment')
axes[1, 1].tick_params(axis='x', rotation=30)

plt.tight_layout()
plt.show()
# Out:
# === CUSTOMER SEGMENT ANALYSIS ===
#
#                   Total Sales  Avg Sales  Total Profit  Avg Profit  \
# Customer Segment
# Consumer           4061897.55   11672.12    1014721.07     2915.87
# Corporate          3840555.70   12388.89     949795.12     3063.86
# Home Office        4178224.05   12217.03    1062833.52     3107.70
#
#                   Order Count  Avg Discount
# Customer Segment
# Consumer                  348         10.45
# Corporate                 310          9.39
# Home Office               342          9.65

# %% [markdown]
# # KEY INSIGHTS AND SUMMARY

# %%
print("\n=== KEY INSIGHTS SUMMARY ===")

# Overall Metrics
total_sales = df['Sales Amount'].sum()
total_profit = df['Profit'].sum()
total_orders = df['Order ID'].nunique()
avg_profit_margin = (total_profit / total_sales) * 100

print("\nOVERALL PERFORMANCE:\n")
print(f"Total Sales: ${total_sales:,.2f}")
print(f"Total Profit: ${total_profit:,.2f}")
print(f"Total Orders: {total_orders}")
print(f"Average Profit Margin: {avg_profit_margin:.2f}%")

# Top Performing Categories
top_categories = df.groupby('Category')['Profit'].sum().sort_values(ascending=False)
print("\nTOP PERFORMING CATEGORIES:\n")
for i, (category, profit) in enumerate(top_categories.items(), 1):
    print(f"{i}. {category}: ${profit:,.2f}")

# Regional Performance
best_region = df.groupby('Region')['Profit'].sum().idxmax()
print(f"\nBEST PERFORMING REGION: {best_region}")

# Delivery Performance
delivery_stats = df['Delivery Status'].value_counts(normalize=True) * 100
print("\nDELIVERY STATUS:")
for status, percentage in delivery_stats.items():
    print(f"{status}: {percentage:.1f}%")

# Customer Segments
best_segment = df.groupby('Customer Segment')['Profit'].sum().idxmax()
print(f"\nMOST PROFITABLE CUSTOMER SEGMENT: {best_segment}")
# Out:
# === KEY INSIGHTS SUMMARY ===
#
# OVERALL PERFORMANCE:
#
# Total Sales: $12,080,677.30
# Total Profit: $3,027,349.71
# Total Orders: 1000
# Average Profit Margin: 25.06%
#
# TOP PERFORMING CATEGORIES:
#
# 1. Grocery: $835,525.28
# 2. Furniture: $757,156.93
# 3. Electronics: $751,262.17
# 4. Office Supplies: $683,405.33
#
# BEST PERFORMING REGION: North
#
# DELIVERY STATUS:
# Returned: 27.5%
# Pending: 25.8%
# Delivered: 24.4%
# Cancelled: 22.3%
#
# MOST PROFITABLE CUSTOMER SEGMENT: Home Office

# %% [markdown]
# # EXPORT RESULTS

# %%
analysis_results = {
    'total_sales': total_sales,
    'total_profit': total_profit,
    'total_orders': total_orders,
    'avg_profit_margin': avg_profit_margin,
    'top_category': top_categories.index[0],
    'best_region': best_region,
    'best_customer_segment': best_segment
}

# Convert to DataFrame and save
results_df = pd.DataFrame([analysis_results])
results_df.to_csv('eda_analysis_summary.csv', index=False)

print("Analysis summary saved to 'eda_analysis_summary.csv'")
# Out:
# Analysis summary saved to 'eda_analysis_summary.csv'
